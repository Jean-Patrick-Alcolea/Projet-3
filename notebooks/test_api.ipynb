# %%
import requests
import pandas as pd
import plotly_express as px
import matplotlib.pyplot as plt

# %%
params = {
    'key' : '2fbbaab3e35841d5ba0125329251906',
    'q' : 'Nantes',
    'days' : 2}

url2 = 'http://api.weatherapi.com/v1/forecast.json'
response2 = requests.get(url2, params=params)
print(response2.status_code)
# Out:
# 200

# %%
lat = 	47.12305
lon = -0.99111

# %%
params = {
    'key' : '2fbbaab3e35841d5ba0125329251906',
    'q' : f'Brest',
    'days' : 7,
    'alerts' : 'yes'}

url2 = 'http://api.weatherapi.com/v1/forecast.json'
response2 = requests.get(url2, params=params)
print(response2.status_code)
data = response2.json()
# Out:
# 200

# %%
data
# Out:
# {'location': {'name': 'Brest',
#   'region': "Brestskaya Voblasts'",
#   'country': 'Belarus',
#   'lat': 52.1,
#   'lon': 23.7,
#   'tz_id': 'Europe/Minsk',
#   'localtime_epoch': 1751985325,
#   'localtime': '2025-07-08 17:35'},
#  'current': {'last_updated_epoch': 1751985000,
#   'last_updated': '2025-07-08 17:30',
#   'temp_c': 25.3,
#   'temp_f': 77.5,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 2.5,
#   'wind_kph': 4.0,
#   'wind_degree': 217,
#   'wind_dir': 'SW',
#   'pressure_mb': 1005.0,
#   'pressure_in': 29.68,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 51,
#   'cloud': 50,
#   'feelslike_c': 26.2,
#   'feelslike_f': 79.1,
#   'windchill_c': 24.0,
#   'windchill_f': 75.1,
#   'heatindex_c': 25.3,
#   'heatindex_f': 77.5,
#   'dewpoint_c': 13.9,
#   'dewpoint_f': 56.9,
#   'vis_km': 9.0,
#   'vis_miles': 5.0,
#   'uv': 2.9,
#   'gust_mph': 3.6,
#   'gust_kph': 5.7},
#  'forecast': {'forecastday': [{'date': '2025-07-08',
#     'date_epoch': 1751932800,
#     'day': {'maxtemp_c': 24.4,
#      'maxtemp_f': 75.9,
#      'mintemp_c': 16.6,
#      'mintemp_f': 61.8,
#      'avgtemp_c': 20.7,
#      'avgtemp_f': 69.2,
#      'maxwind_mph': 9.2,
#      'maxwind_kph': 14.8,
#      'totalprecip_mm': 0.53,
#      'totalprecip_in': 0.02,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.0,
#      'avgvis_miles': 5.0,
#      'avghumidity': 71,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 85,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain nearby',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 2.1},
#     'astro': {'sunrise': '05:15 AM',
#      'sunset': '09:45 PM',
#      'moonrise': '08:37 PM',
#      'moonset': '02:15 AM',
#      'moon_phase': 'Waxing Gibbous',
#      'moon_illumination': 92,
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1751922000,
#       'time': '2025-07-08 00:00',
#       'temp_c': 17.7,
#       'temp_f': 63.8,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 271,
#       'wind_dir': 'W',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.61,
#       'precip_mm': 0.17,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 95,
#       'cloud': 100,
#       'feelslike_c': 17.7,
#       'feelslike_f': 63.8,
#       'windchill_c': 17.7,
#       'windchill_f': 63.8,
#       'heatindex_c': 17.7,
#       'heatindex_f': 63.8,
#       'dewpoint_c': 16.8,
#       'dewpoint_f': 62.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 0},
#      {'time_epoch': 1751925600,
#       'time': '2025-07-08 01:00',
#       'temp_c': 17.7,
#       'temp_f': 63.9,
#       'is_day': 0,
#       'condition': {'text': 'Mist',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#        'code': 1030},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.62,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 94,
#       'cloud': 87,
#       'feelslike_c': 17.7,
#       'feelslike_f': 63.9,
#       'windchill_c': 17.7,
#       'windchill_f': 63.9,
#       'heatindex_c': 17.7,
#       'heatindex_f': 63.9,
#       'dewpoint_c': 16.8,
#       'dewpoint_f': 62.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 62,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 6.9,
#       'gust_kph': 11.2,
#       'uv': 0},
#      {'time_epoch': 1751929200,
#       'time': '2025-07-08 02:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 247,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.62,
#       'precip_mm': 0.15,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 95,
#       'cloud': 100,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'dewpoint_c': 16.9,
#       'dewpoint_f': 62.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.1,
#       'uv': 0},
#      {'time_epoch': 1751932800,
#       'time': '2025-07-08 03:00',
#       'temp_c': 17.2,
#       'temp_f': 63.0,
#       'is_day': 0,
#       'condition': {'text': 'Mist',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#        'code': 1030},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 267,
#       'wind_dir': 'W',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.62,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 97,
#       'cloud': 100,
#       'feelslike_c': 17.2,
#       'feelslike_f': 63.0,
#       'windchill_c': 17.2,
#       'windchill_f': 63.0,
#       'heatindex_c': 17.2,
#       'heatindex_f': 63.0,
#       'dewpoint_c': 16.7,
#       'dewpoint_f': 62.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 63,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 10.4,
#       'gust_kph': 16.7,
#       'uv': 0},
#      {'time_epoch': 1751936400,
#       'time': '2025-07-08 04:00',
#       'temp_c': 16.9,
#       'temp_f': 62.3,
#       'is_day': 0,
#       'condition': {'text': 'Mist',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#        'code': 1030},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 300,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.63,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 97,
#       'cloud': 100,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.3,
#       'windchill_c': 16.9,
#       'windchill_f': 62.3,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.3,
#       'dewpoint_c': 16.4,
#       'dewpoint_f': 61.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 84,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 0},
#      {'time_epoch': 1751940000,
#       'time': '2025-07-08 05:00',
#       'temp_c': 16.6,
#       'temp_f': 61.9,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 294,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.62,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 96,
#       'cloud': 100,
#       'feelslike_c': 16.6,
#       'feelslike_f': 61.9,
#       'windchill_c': 16.6,
#       'windchill_f': 61.9,
#       'heatindex_c': 16.6,
#       'heatindex_f': 61.9,
#       'dewpoint_c': 16.0,
#       'dewpoint_f': 60.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 85,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 0},
#      {'time_epoch': 1751943600,
#       'time': '2025-07-08 06:00',
#       'temp_c': 16.6,
#       'temp_f': 61.8,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 294,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.64,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 95,
#       'cloud': 100,
#       'feelslike_c': 16.6,
#       'feelslike_f': 61.8,
#       'windchill_c': 16.6,
#       'windchill_f': 61.8,
#       'heatindex_c': 16.6,
#       'heatindex_f': 61.8,
#       'dewpoint_c': 15.8,
#       'dewpoint_f': 60.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 61,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 0.1},
#      {'time_epoch': 1751947200,
#       'time': '2025-07-08 07:00',
#       'temp_c': 17.5,
#       'temp_f': 63.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 285,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.66,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.5,
#       'windchill_c': 17.5,
#       'windchill_f': 63.5,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.5,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 66,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.8,
#       'gust_kph': 17.3,
#       'uv': 0.4},
#      {'time_epoch': 1751950800,
#       'time': '2025-07-08 08:00',
#       'temp_c': 18.6,
#       'temp_f': 65.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 280,
#       'wind_dir': 'W',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.68,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 18.6,
#       'feelslike_f': 65.5,
#       'windchill_c': 18.6,
#       'windchill_f': 65.5,
#       'heatindex_c': 18.6,
#       'heatindex_f': 65.5,
#       'dewpoint_c': 15.6,
#       'dewpoint_f': 60.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 62,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.2,
#       'gust_kph': 16.4,
#       'uv': 1.0},
#      {'time_epoch': 1751954400,
#       'time': '2025-07-08 09:00',
#       'temp_c': 19.9,
#       'temp_f': 67.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 286,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 73,
#       'cloud': 90,
#       'feelslike_c': 19.9,
#       'feelslike_f': 67.9,
#       'windchill_c': 19.9,
#       'windchill_f': 67.9,
#       'heatindex_c': 19.9,
#       'heatindex_f': 67.9,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 59.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 62,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.5,
#       'gust_kph': 15.3,
#       'uv': 2.0},
#      {'time_epoch': 1751958000,
#       'time': '2025-07-08 10:00',
#       'temp_c': 21.7,
#       'temp_f': 71.0,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 280,
#       'wind_dir': 'W',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.7,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 62,
#       'cloud': 85,
#       'feelslike_c': 21.7,
#       'feelslike_f': 71.0,
#       'windchill_c': 21.7,
#       'windchill_f': 71.0,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 77,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.2,
#       'gust_kph': 13.2,
#       'uv': 3.5},
#      {'time_epoch': 1751961600,
#       'time': '2025-07-08 11:00',
#       'temp_c': 23.1,
#       'temp_f': 73.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 272,
#       'wind_dir': 'W',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 94,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.8,
#       'windchill_c': 23.1,
#       'windchill_f': 73.6,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.8,
#       'dewpoint_c': 13.6,
#       'dewpoint_f': 56.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 64,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.5,
#       'gust_kph': 12.0,
#       'uv': 5.2},
#      {'time_epoch': 1751965200,
#       'time': '2025-07-08 12:00',
#       'temp_c': 24.0,
#       'temp_f': 75.2,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 258,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 78,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.4,
#       'windchill_c': 24.0,
#       'windchill_f': 75.2,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.4,
#       'dewpoint_c': 13.1,
#       'dewpoint_f': 55.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.4,
#       'gust_kph': 10.4,
#       'uv': 6.6},
#      {'time_epoch': 1751968800,
#       'time': '2025-07-08 13:00',
#       'temp_c': 24.4,
#       'temp_f': 75.8,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 48,
#       'cloud': 100,
#       'feelslike_c': 25.3,
#       'feelslike_f': 77.6,
#       'windchill_c': 24.4,
#       'windchill_f': 75.8,
#       'heatindex_c': 25.3,
#       'heatindex_f': 77.6,
#       'dewpoint_c': 12.7,
#       'dewpoint_f': 54.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.9,
#       'uv': 7.3},
#      {'time_epoch': 1751972400,
#       'time': '2025-07-08 14:00',
#       'temp_c': 24.2,
#       'temp_f': 75.5,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 199,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 48,
#       'cloud': 78,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.4,
#       'windchill_c': 24.2,
#       'windchill_f': 75.5,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.4,
#       'dewpoint_c': 12.6,
#       'dewpoint_f': 54.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.3,
#       'uv': 7.3},
#      {'time_epoch': 1751976000,
#       'time': '2025-07-08 15:00',
#       'temp_c': 24.2,
#       'temp_f': 75.6,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 194,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 66,
#       'feelslike_c': 25.3,
#       'feelslike_f': 77.6,
#       'windchill_c': 24.2,
#       'windchill_f': 75.6,
#       'heatindex_c': 25.3,
#       'heatindex_f': 77.6,
#       'dewpoint_c': 13.2,
#       'dewpoint_f': 55.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 10.0,
#       'uv': 6.4},
#      {'time_epoch': 1751979600,
#       'time': '2025-07-08 16:00',
#       'temp_c': 24.4,
#       'temp_f': 75.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 209,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 49,
#       'feelslike_c': 25.4,
#       'feelslike_f': 77.7,
#       'windchill_c': 24.4,
#       'windchill_f': 75.9,
#       'heatindex_c': 25.4,
#       'heatindex_f': 77.7,
#       'dewpoint_c': 13.3,
#       'dewpoint_f': 55.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.0,
#       'gust_kph': 9.6,
#       'uv': 4.9},
#      {'time_epoch': 1751983200,
#       'time': '2025-07-08 17:00',
#       'temp_c': 25.3,
#       'temp_f': 77.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 217,
#       'wind_dir': 'SW',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.68,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 50,
#       'feelslike_c': 25.3,
#       'feelslike_f': 77.5,
#       'windchill_c': 24.0,
#       'windchill_f': 75.1,
#       'heatindex_c': 25.3,
#       'heatindex_f': 77.5,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 56.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 3.6,
#       'gust_kph': 5.7,
#       'uv': 2.9},
#      {'time_epoch': 1751986800,
#       'time': '2025-07-08 18:00',
#       'temp_c': 23.7,
#       'temp_f': 74.6,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 1.6,
#       'wind_kph': 2.5,
#       'wind_degree': 181,
#       'wind_dir': 'S',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 45,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.4,
#       'windchill_c': 23.7,
#       'windchill_f': 74.6,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.4,
#       'dewpoint_c': 14.7,
#       'dewpoint_f': 58.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.3,
#       'gust_kph': 3.8,
#       'uv': 1.9},
#      {'time_epoch': 1751990400,
#       'time': '2025-07-08 19:00',
#       'temp_c': 23.5,
#       'temp_f': 74.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 0.9,
#       'wind_kph': 1.4,
#       'wind_degree': 79,
#       'wind_dir': 'E',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.7,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 61,
#       'cloud': 49,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.3,
#       'windchill_c': 23.5,
#       'windchill_f': 74.3,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.3,
#       'dewpoint_c': 15.4,
#       'dewpoint_f': 59.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.4,
#       'gust_kph': 2.2,
#       'uv': 0.7},
#      {'time_epoch': 1751994000,
#       'time': '2025-07-08 20:00',
#       'temp_c': 21.7,
#       'temp_f': 71.0,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 50,
#       'wind_dir': 'NE',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 44,
#       'feelslike_c': 21.7,
#       'feelslike_f': 71.0,
#       'windchill_c': 21.7,
#       'windchill_f': 71.0,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.3,
#       'gust_kph': 15.0,
#       'uv': 0.3},
#      {'time_epoch': 1751997600,
#       'time': '2025-07-08 21:00',
#       'temp_c': 20.6,
#       'temp_f': 69.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 43,
#       'wind_dir': 'NE',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.68,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 16,
#       'feelslike_c': 20.6,
#       'feelslike_f': 69.2,
#       'windchill_c': 20.6,
#       'windchill_f': 69.2,
#       'heatindex_c': 20.6,
#       'heatindex_f': 69.2,
#       'dewpoint_c': 13.4,
#       'dewpoint_f': 56.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.6,
#       'gust_kph': 20.2,
#       'uv': 0.0},
#      {'time_epoch': 1752001200,
#       'time': '2025-07-08 22:00',
#       'temp_c': 20.2,
#       'temp_f': 68.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 73,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 35,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.3,
#       'windchill_c': 20.2,
#       'windchill_f': 68.3,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.3,
#       'dewpoint_c': 13.0,
#       'dewpoint_f': 55.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.0,
#       'gust_kph': 22.5,
#       'uv': 0},
#      {'time_epoch': 1752004800,
#       'time': '2025-07-08 23:00',
#       'temp_c': 19.8,
#       'temp_f': 67.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 82,
#       'wind_dir': 'E',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 65,
#       'cloud': 48,
#       'feelslike_c': 19.8,
#       'feelslike_f': 67.7,
#       'windchill_c': 19.8,
#       'windchill_f': 67.7,
#       'heatindex_c': 19.8,
#       'heatindex_f': 67.7,
#       'dewpoint_c': 13.1,
#       'dewpoint_f': 55.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.8,
#       'gust_kph': 17.4,
#       'uv': 0}]},
#    {'date': '2025-07-09',
#     'date_epoch': 1752019200,
#     'day': {'maxtemp_c': 18.9,
#      'maxtemp_f': 65.9,
#      'mintemp_c': 15.3,
#      'mintemp_f': 59.6,
#      'avgtemp_c': 17.0,
#      'avgtemp_f': 62.7,
#      'maxwind_mph': 12.1,
#      'maxwind_kph': 19.4,
#      'totalprecip_mm': 13.58,
#      'totalprecip_in': 0.53,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.1,
#      'avgvis_miles': 5.0,
#      'avghumidity': 94,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 92,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Moderate rain',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#       'code': 1189},
#      'uv': 1.3},
#     'astro': {'sunrise': '05:16 AM',
#      'sunset': '09:45 PM',
#      'moonrise': '09:32 PM',
#      'moonset': '02:58 AM',
#      'moon_phase': 'Waxing Gibbous',
#      'moon_illumination': 96,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1752008400,
#       'time': '2025-07-09 00:00',
#       'temp_c': 18.5,
#       'temp_f': 65.3,
#       'is_day': 0,
#       'condition': {'text': 'Patchy light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/263.png',
#        'code': 1150},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 144,
#       'wind_dir': 'SE',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.39,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 76,
#       'cloud': 51,
#       'feelslike_c': 18.5,
#       'feelslike_f': 65.3,
#       'windchill_c': 18.5,
#       'windchill_f': 65.3,
#       'heatindex_c': 18.5,
#       'heatindex_f': 65.3,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 5.0,
#       'vis_miles': 3.0,
#       'gust_mph': 9.5,
#       'gust_kph': 15.2,
#       'uv': 0},
#      {'time_epoch': 1752012000,
#       'time': '2025-07-09 01:00',
#       'temp_c': 16.7,
#       'temp_f': 62.0,
#       'is_day': 0,
#       'condition': {'text': 'Patchy light rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/293.png',
#        'code': 1180},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 167,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 1.3,
#       'precip_in': 0.05,
#       'snow_cm': 0.0,
#       'humidity': 93,
#       'cloud': 53,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.0,
#       'windchill_c': 16.7,
#       'windchill_f': 62.0,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.0,
#       'dewpoint_c': 15.6,
#       'dewpoint_f': 60.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 9.3,
#       'gust_kph': 14.9,
#       'uv': 0},
#      {'time_epoch': 1752015600,
#       'time': '2025-07-09 02:00',
#       'temp_c': 16.4,
#       'temp_f': 61.5,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 0.9,
#       'wind_kph': 1.4,
#       'wind_degree': 204,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.7,
#       'precip_mm': 0.91,
#       'precip_in': 0.04,
#       'snow_cm': 0.0,
#       'humidity': 97,
#       'cloud': 84,
#       'feelslike_c': 16.4,
#       'feelslike_f': 61.5,
#       'windchill_c': 16.4,
#       'windchill_f': 61.5,
#       'heatindex_c': 16.4,
#       'heatindex_f': 61.5,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.4,
#       'gust_kph': 2.3,
#       'uv': 0},
#      {'time_epoch': 1752019200,
#       'time': '2025-07-09 03:00',
#       'temp_c': 16.2,
#       'temp_f': 61.2,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 322,
#       'wind_dir': 'NW',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.69,
#       'precip_mm': 1.04,
#       'precip_in': 0.04,
#       'snow_cm': 0.0,
#       'humidity': 98,
#       'cloud': 84,
#       'feelslike_c': 16.3,
#       'feelslike_f': 61.3,
#       'windchill_c': 16.3,
#       'windchill_f': 61.3,
#       'heatindex_c': 16.3,
#       'heatindex_f': 61.3,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 0},
#      {'time_epoch': 1752022800,
#       'time': '2025-07-09 04:00',
#       'temp_c': 16.1,
#       'temp_f': 61.1,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 331,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.67,
#       'precip_mm': 0.32,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 98,
#       'cloud': 91,
#       'feelslike_c': 16.1,
#       'feelslike_f': 61.1,
#       'windchill_c': 16.1,
#       'windchill_f': 61.1,
#       'heatindex_c': 16.1,
#       'heatindex_f': 61.1,
#       'dewpoint_c': 15.8,
#       'dewpoint_f': 60.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.8,
#       'gust_kph': 14.2,
#       'uv': 0},
#      {'time_epoch': 1752026400,
#       'time': '2025-07-09 05:00',
#       'temp_c': 16.2,
#       'temp_f': 61.2,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 354,
#       'wind_dir': 'N',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.66,
#       'precip_mm': 2.13,
#       'precip_in': 0.08,
#       'snow_cm': 0.0,
#       'humidity': 98,
#       'cloud': 100,
#       'feelslike_c': 16.2,
#       'feelslike_f': 61.2,
#       'windchill_c': 16.2,
#       'windchill_f': 61.2,
#       'heatindex_c': 16.2,
#       'heatindex_f': 61.2,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.5,
#       'gust_kph': 17.0,
#       'uv': 0},
#      {'time_epoch': 1752030000,
#       'time': '2025-07-09 06:00',
#       'temp_c': 16.3,
#       'temp_f': 61.4,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 12,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.65,
#       'precip_mm': 1.9,
#       'precip_in': 0.07,
#       'snow_cm': 0.0,
#       'humidity': 98,
#       'cloud': 100,
#       'feelslike_c': 16.3,
#       'feelslike_f': 61.4,
#       'windchill_c': 16.3,
#       'windchill_f': 61.4,
#       'heatindex_c': 16.3,
#       'heatindex_f': 61.4,
#       'dewpoint_c': 16.0,
#       'dewpoint_f': 60.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.4,
#       'gust_kph': 19.9,
#       'uv': 0.0},
#      {'time_epoch': 1752033600,
#       'time': '2025-07-09 07:00',
#       'temp_c': 16.6,
#       'temp_f': 61.8,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 24,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.65,
#       'precip_mm': 0.9,
#       'precip_in': 0.04,
#       'snow_cm': 0.0,
#       'humidity': 98,
#       'cloud': 100,
#       'feelslike_c': 16.6,
#       'feelslike_f': 61.8,
#       'windchill_c': 16.6,
#       'windchill_f': 61.8,
#       'heatindex_c': 16.6,
#       'heatindex_f': 61.8,
#       'dewpoint_c': 16.2,
#       'dewpoint_f': 61.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.0,
#       'gust_kph': 21.0,
#       'uv': 0.0},
#      {'time_epoch': 1752037200,
#       'time': '2025-07-09 08:00',
#       'temp_c': 16.9,
#       'temp_f': 62.5,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 31,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.65,
#       'precip_mm': 0.47,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 97,
#       'cloud': 100,
#       'feelslike_c': 17.0,
#       'feelslike_f': 62.5,
#       'windchill_c': 17.0,
#       'windchill_f': 62.5,
#       'heatindex_c': 17.0,
#       'heatindex_f': 62.5,
#       'dewpoint_c': 16.4,
#       'dewpoint_f': 61.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.0,
#       'gust_kph': 20.9,
#       'uv': 0.0},
#      {'time_epoch': 1752040800,
#       'time': '2025-07-09 09:00',
#       'temp_c': 17.2,
#       'temp_f': 63.0,
#       'is_day': 1,
#       'condition': {'text': 'Light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/266.png',
#        'code': 1153},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 39,
#       'wind_dir': 'NE',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.66,
#       'precip_mm': 0.43,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 96,
#       'cloud': 100,
#       'feelslike_c': 17.2,
#       'feelslike_f': 63.0,
#       'windchill_c': 17.2,
#       'windchill_f': 63.0,
#       'heatindex_c': 17.2,
#       'heatindex_f': 63.0,
#       'dewpoint_c': 16.6,
#       'dewpoint_f': 61.9,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 10.8,
#       'gust_kph': 17.3,
#       'uv': 0.2},
#      {'time_epoch': 1752044400,
#       'time': '2025-07-09 10:00',
#       'temp_c': 17.5,
#       'temp_f': 63.6,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 52,
#       'wind_dir': 'NE',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.67,
#       'precip_mm': 0.51,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 96,
#       'cloud': 100,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.6,
#       'windchill_c': 17.5,
#       'windchill_f': 63.6,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.6,
#       'dewpoint_c': 16.8,
#       'dewpoint_f': 62.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.3,
#       'gust_kph': 11.7,
#       'uv': 1.2},
#      {'time_epoch': 1752048000,
#       'time': '2025-07-09 11:00',
#       'temp_c': 17.8,
#       'temp_f': 64.0,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 52,
#       'wind_dir': 'NE',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.68,
#       'precip_mm': 0.5,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 94,
#       'cloud': 100,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.0,
#       'windchill_c': 17.8,
#       'windchill_f': 64.0,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.0,
#       'dewpoint_c': 16.8,
#       'dewpoint_f': 62.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 4.2},
#      {'time_epoch': 1752051600,
#       'time': '2025-07-09 12:00',
#       'temp_c': 18.4,
#       'temp_f': 65.2,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 28,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.68,
#       'precip_mm': 0.36,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': 18.5,
#       'feelslike_f': 65.2,
#       'windchill_c': 18.5,
#       'windchill_f': 65.2,
#       'heatindex_c': 18.5,
#       'heatindex_f': 65.2,
#       'dewpoint_c': 16.8,
#       'dewpoint_f': 62.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.3,
#       'gust_kph': 6.9,
#       'uv': 4.8},
#      {'time_epoch': 1752055200,
#       'time': '2025-07-09 13:00',
#       'temp_c': 18.9,
#       'temp_f': 65.9,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 6,
#       'wind_dir': 'N',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.44,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 89,
#       'cloud': 100,
#       'feelslike_c': 18.9,
#       'feelslike_f': 65.9,
#       'windchill_c': 18.9,
#       'windchill_f': 65.9,
#       'heatindex_c': 18.9,
#       'heatindex_f': 65.9,
#       'dewpoint_c': 16.9,
#       'dewpoint_f': 62.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.5,
#       'gust_kph': 12.1,
#       'uv': 5.7},
#      {'time_epoch': 1752058800,
#       'time': '2025-07-09 14:00',
#       'temp_c': 18.7,
#       'temp_f': 65.6,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 351,
#       'wind_dir': 'N',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.81,
#       'precip_in': 0.03,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.6,
#       'windchill_c': 18.7,
#       'windchill_f': 65.6,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.6,
#       'dewpoint_c': 17.1,
#       'dewpoint_f': 62.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 5.0},
#      {'time_epoch': 1752062400,
#       'time': '2025-07-09 15:00',
#       'temp_c': 18.4,
#       'temp_f': 65.2,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 343,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.69,
#       'precip_mm': 0.51,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 91,
#       'cloud': 100,
#       'feelslike_c': 18.4,
#       'feelslike_f': 65.2,
#       'windchill_c': 18.4,
#       'windchill_f': 65.2,
#       'heatindex_c': 18.4,
#       'heatindex_f': 65.2,
#       'dewpoint_c': 17.0,
#       'dewpoint_f': 62.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.4,
#       'gust_kph': 23.1,
#       'uv': 3.8},
#      {'time_epoch': 1752066000,
#       'time': '2025-07-09 16:00',
#       'temp_c': 18.0,
#       'temp_f': 64.3,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 342,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.42,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 92,
#       'cloud': 100,
#       'feelslike_c': 18.0,
#       'feelslike_f': 64.3,
#       'windchill_c': 18.0,
#       'windchill_f': 64.3,
#       'heatindex_c': 18.0,
#       'heatindex_f': 64.3,
#       'dewpoint_c': 16.7,
#       'dewpoint_f': 62.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.7,
#       'gust_kph': 26.9,
#       'uv': 2.6},
#      {'time_epoch': 1752069600,
#       'time': '2025-07-09 17:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 341,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.72,
#       'precip_mm': 0.18,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 93,
#       'cloud': 100,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 16.3,
#       'dewpoint_f': 61.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.5,
#       'gust_kph': 26.5,
#       'uv': 1.9},
#      {'time_epoch': 1752073200,
#       'time': '2025-07-09 18:00',
#       'temp_c': 16.9,
#       'temp_f': 62.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 349,
#       'wind_dir': 'N',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.74,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 93,
#       'cloud': 91,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.4,
#       'windchill_c': 16.9,
#       'windchill_f': 62.4,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.4,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 80,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.7,
#       'gust_kph': 26.9,
#       'uv': 0.7},
#      {'time_epoch': 1752076800,
#       'time': '2025-07-09 19:00',
#       'temp_c': 16.7,
#       'temp_f': 62.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 352,
#       'wind_dir': 'N',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.75,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 92,
#       'cloud': 91,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.0,
#       'windchill_c': 16.7,
#       'windchill_f': 62.0,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.0,
#       'dewpoint_c': 15.3,
#       'dewpoint_f': 59.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.6,
#       'gust_kph': 21.9,
#       'uv': 0.2},
#      {'time_epoch': 1752080400,
#       'time': '2025-07-09 20:00',
#       'temp_c': 16.6,
#       'temp_f': 61.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 337,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.77,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 92,
#       'cloud': 70,
#       'feelslike_c': 16.6,
#       'feelslike_f': 61.9,
#       'windchill_c': 16.6,
#       'windchill_f': 61.9,
#       'heatindex_c': 16.6,
#       'heatindex_f': 61.9,
#       'dewpoint_c': 15.3,
#       'dewpoint_f': 59.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 61,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.0,
#       'gust_kph': 20.9,
#       'uv': 0.1},
#      {'time_epoch': 1752084000,
#       'time': '2025-07-09 21:00',
#       'temp_c': 15.8,
#       'temp_f': 60.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 329,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.77,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 94,
#       'cloud': 70,
#       'feelslike_c': 15.8,
#       'feelslike_f': 60.5,
#       'windchill_c': 15.8,
#       'windchill_f': 60.5,
#       'heatindex_c': 15.8,
#       'heatindex_f': 60.5,
#       'dewpoint_c': 14.9,
#       'dewpoint_f': 58.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 65,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.7,
#       'gust_kph': 22.1,
#       'uv': 0.0},
#      {'time_epoch': 1752087600,
#       'time': '2025-07-09 22:00',
#       'temp_c': 15.3,
#       'temp_f': 59.6,
#       'is_day': 0,
#       'condition': {'text': 'Mist',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#        'code': 1030},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 318,
#       'wind_dir': 'NW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.78,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 96,
#       'cloud': 75,
#       'feelslike_c': 15.3,
#       'feelslike_f': 59.6,
#       'windchill_c': 15.3,
#       'windchill_f': 59.6,
#       'heatindex_c': 15.3,
#       'heatindex_f': 59.6,
#       'dewpoint_c': 14.7,
#       'dewpoint_f': 58.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 12.6,
#       'gust_kph': 20.2,
#       'uv': 0},
#      {'time_epoch': 1752091200,
#       'time': '2025-07-09 23:00',
#       'temp_c': 15.3,
#       'temp_f': 59.6,
# ...
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 93,
#       'cloud': 100,
#       'feelslike_c': 15.3,
#       'feelslike_f': 59.5,
#       'windchill_c': 15.3,
#       'windchill_f': 59.5,
#       'heatindex_c': 15.3,
#       'heatindex_f': 59.5,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 84,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.3,
#       'uv': 0.0},
#      {'time_epoch': 1752123600,
#       'time': '2025-07-10 08:00',
#       'temp_c': 16.6,
#       'temp_f': 61.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 13.2,
#       'wind_kph': 21.2,
#       'wind_degree': 339,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.8,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 100,
#       'feelslike_c': 16.6,
#       'feelslike_f': 61.9,
#       'windchill_c': 16.6,
#       'windchill_f': 61.9,
#       'heatindex_c': 16.6,
#       'heatindex_f': 61.9,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 73,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.1,
#       'gust_kph': 27.5,
#       'uv': 0.1},
#      {'time_epoch': 1752127200,
#       'time': '2025-07-10 09:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 13.6,
#       'wind_kph': 22.0,
#       'wind_degree': 344,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.8,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 81,
#       'cloud': 100,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 66,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.9,
#       'gust_kph': 27.1,
#       'uv': 0.2},
#      {'time_epoch': 1752130800,
#       'time': '2025-07-10 10:00',
#       'temp_c': 17.2,
#       'temp_f': 63.0,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 347,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.81,
#       'precip_mm': 0.05,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.1,
#       'windchill_c': 17.3,
#       'windchill_f': 63.1,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.1,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 77,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.5,
#       'gust_kph': 25.0,
#       'uv': 0.2},
#      {'time_epoch': 1752134400,
#       'time': '2025-07-10 11:00',
#       'temp_c': 16.8,
#       'temp_f': 62.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 350,
#       'wind_dir': 'N',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.81,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 100,
#       'feelslike_c': 16.8,
#       'feelslike_f': 62.3,
#       'windchill_c': 16.8,
#       'windchill_f': 62.3,
#       'heatindex_c': 16.8,
#       'heatindex_f': 62.3,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 60,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.6,
#       'gust_kph': 23.5,
#       'uv': 0.3},
#      {'time_epoch': 1752138000,
#       'time': '2025-07-10 12:00',
#       'temp_c': 17.1,
#       'temp_f': 62.8,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 354,
#       'wind_dir': 'N',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.82,
#       'precip_mm': 0.06,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.8,
#       'windchill_c': 17.1,
#       'windchill_f': 62.8,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.8,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.6,
#       'uv': 0.4},
#      {'time_epoch': 1752141600,
#       'time': '2025-07-10 13:00',
#       'temp_c': 17.0,
#       'temp_f': 62.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 0,
#       'wind_dir': 'N',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.05,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 17.0,
#       'feelslike_f': 62.7,
#       'windchill_c': 17.0,
#       'windchill_f': 62.7,
#       'heatindex_c': 17.0,
#       'heatindex_f': 62.7,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 81,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.3,
#       'gust_kph': 23.0,
#       'uv': 0.5},
#      {'time_epoch': 1752145200,
#       'time': '2025-07-10 14:00',
#       'temp_c': 16.9,
#       'temp_f': 62.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 355,
#       'wind_dir': 'N',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.05,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 100,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.3,
#       'windchill_c': 16.9,
#       'windchill_f': 62.3,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.3,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 72,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.3,
#       'gust_kph': 23.0,
#       'uv': 0.4},
#      {'time_epoch': 1752148800,
#       'time': '2025-07-10 15:00',
#       'temp_c': 16.7,
#       'temp_f': 62.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 0,
#       'wind_dir': 'N',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.08,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 100,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.1,
#       'windchill_c': 16.7,
#       'windchill_f': 62.1,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.1,
#       'dewpoint_c': 14.0,
#       'dewpoint_f': 57.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 0.5},
#      {'time_epoch': 1752152400,
#       'time': '2025-07-10 16:00',
#       'temp_c': 16.5,
#       'temp_f': 61.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 356,
#       'wind_dir': 'N',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.06,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 85,
#       'cloud': 100,
#       'feelslike_c': 16.5,
#       'feelslike_f': 61.7,
#       'windchill_c': 16.5,
#       'windchill_f': 61.7,
#       'heatindex_c': 16.5,
#       'heatindex_f': 61.7,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 57.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.1,
#       'gust_kph': 25.8,
#       'uv': 0.5},
#      {'time_epoch': 1752156000,
#       'time': '2025-07-10 17:00',
#       'temp_c': 16.1,
#       'temp_f': 61.0,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.8,
#       'wind_kph': 20.5,
#       'wind_degree': 348,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.08,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 87,
#       'cloud': 100,
#       'feelslike_c': 16.1,
#       'feelslike_f': 61.0,
#       'windchill_c': 16.1,
#       'windchill_f': 61.0,
#       'heatindex_c': 16.1,
#       'heatindex_f': 61.0,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 57.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.9,
#       'gust_kph': 27.3,
#       'uv': 0.3},
#      {'time_epoch': 1752159600,
#       'time': '2025-07-10 18:00',
#       'temp_c': 16.1,
#       'temp_f': 60.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 354,
#       'wind_dir': 'N',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 87,
#       'cloud': 100,
#       'feelslike_c': 16.1,
#       'feelslike_f': 60.9,
#       'windchill_c': 16.1,
#       'windchill_f': 60.9,
#       'heatindex_c': 16.1,
#       'heatindex_f': 60.9,
#       'dewpoint_c': 14.0,
#       'dewpoint_f': 57.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 80,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.0,
#       'gust_kph': 25.7,
#       'uv': 0.2},
#      {'time_epoch': 1752163200,
#       'time': '2025-07-10 19:00',
#       'temp_c': 15.5,
#       'temp_f': 59.8,
#       'is_day': 1,
#       'condition': {'text': 'Light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/266.png',
#        'code': 1153},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 356,
#       'wind_dir': 'N',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.4,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 91,
#       'cloud': 100,
#       'feelslike_c': 15.5,
#       'feelslike_f': 59.8,
#       'windchill_c': 15.5,
#       'windchill_f': 59.8,
#       'heatindex_c': 15.5,
#       'heatindex_f': 59.8,
#       'dewpoint_c': 14.0,
#       'dewpoint_f': 57.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 14.0,
#       'gust_kph': 22.6,
#       'uv': 0.1},
#      {'time_epoch': 1752166800,
#       'time': '2025-07-10 20:00',
#       'temp_c': 14.7,
#       'temp_f': 58.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 337,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.8,
#       'precip_mm': 0.07,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 95,
#       'cloud': 100,
#       'feelslike_c': 13.5,
#       'feelslike_f': 56.2,
#       'windchill_c': 13.5,
#       'windchill_f': 56.2,
#       'heatindex_c': 14.7,
#       'heatindex_f': 58.5,
#       'dewpoint_c': 14.0,
#       'dewpoint_f': 57.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.4,
#       'uv': 0.0},
#      {'time_epoch': 1752170400,
#       'time': '2025-07-10 21:00',
#       'temp_c': 14.7,
#       'temp_f': 58.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 341,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.81,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 95,
#       'cloud': 100,
#       'feelslike_c': 13.4,
#       'feelslike_f': 56.1,
#       'windchill_c': 13.4,
#       'windchill_f': 56.1,
#       'heatindex_c': 14.7,
#       'heatindex_f': 58.5,
#       'dewpoint_c': 14.0,
#       'dewpoint_f': 57.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 80,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.9,
#       'gust_kph': 28.7,
#       'uv': 0.0},
#      {'time_epoch': 1752174000,
#       'time': '2025-07-10 22:00',
#       'temp_c': 14.6,
#       'temp_f': 58.3,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 343,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.8,
#       'precip_mm': 0.05,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 95,
#       'cloud': 100,
#       'feelslike_c': 13.2,
#       'feelslike_f': 55.8,
#       'windchill_c': 13.2,
#       'windchill_f': 55.8,
#       'heatindex_c': 14.6,
#       'heatindex_f': 58.3,
#       'dewpoint_c': 13.8,
#       'dewpoint_f': 56.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.3,
#       'gust_kph': 29.5,
#       'uv': 0},
#      {'time_epoch': 1752177600,
#       'time': '2025-07-10 23:00',
#       'temp_c': 14.3,
#       'temp_f': 57.8,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 338,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.79,
#       'precip_mm': 0.13,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 95,
#       'cloud': 100,
#       'feelslike_c': 12.8,
#       'feelslike_f': 55.0,
#       'windchill_c': 12.8,
#       'windchill_f': 55.0,
#       'heatindex_c': 14.3,
#       'heatindex_f': 57.8,
#       'dewpoint_c': 13.5,
#       'dewpoint_f': 56.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.2,
#       'gust_kph': 30.9,
#       'uv': 0}]}]},
#  'alerts': {'alert': []}}

# %%
df = pd.DataFrame()

# %%
df['lat'] = [data['location']['lat']]
df['lon'] = [data['location']['lon']]

# %%
if len(data['alerts']['alert']) == 0:
    df['alert'] = ['No alert']
else:
    df['alert'] = [data['alerts']['alert'][0]['event']]
    df['alert_debut'] = [data['alerts']['alert'][0]['effective']]
    df['alert_fin'] = [data['alerts']['alert'][0]['expires']]
    df['alert_severity'] = [data['alerts']['alert'][0]['severity']]

# %%
df
# Out:
#      lat   lon                      alert                alert_debut  \
# 0  45.75  4.85  Vigilance orange canicule  2025-06-25T00:00:00+02:00
#
#                    alert_fin alert_severity
# 0  2025-06-26T00:00:00+02:00         Severe

# %%
df_meteo = pd.DataFrame()

# %%
data_2 = []
for day in data['forecast']['forecastday']:
    data_2.append({
        'date': day['date'],
        'max_temp': day['day']['maxtemp_c'],
        'min_temp': day['day']['mintemp_c'],
        'avg_temp': day['day']['avgtemp_c'],
        'totalprecip_mm': day['day']['totalprecip_mm'],
        'avghumidity': day['day']['avghumidity'],
        'daily_will_it_rain': day['day']['daily_will_it_rain'],
        'daily_chance_of_rain': day['day']['daily_chance_of_rain'],
        'daily_will_it_snow': day['day']['daily_will_it_snow'],
        'daily_chance_of_snow': day['day']['daily_chance_of_snow'],
        'condition_text': day['day']['condition']['text'],
        'condition_icon': day['day']['condition']['icon']
    })

# %%
df_meteo= pd.DataFrame(data_2)

# %%
df_meteo
# Out:
#          date  max_temp  min_temp  avg_temp  totalprecip_mm  avghumidity  \
# 0  2025-06-24      32.2      16.6      24.8            0.00           43
# 1  2025-06-25      36.6      18.7      27.3            1.89           42
# 2  2025-06-26      29.3      17.8      23.2            1.52           66
# 3  2025-06-27      30.4      17.1      23.8            0.00           57
# 4  2025-06-28      32.1      18.0      25.2            0.00           49
# 5  2025-06-29      34.0      18.8      25.6            0.00           47
# 6  2025-06-30      35.5      20.3      28.0            0.00           38
#
#    daily_will_it_rain  daily_chance_of_rain  daily_will_it_snow  \
# 0                   0                     0                   0
# 1                   0                    69                   0
# 2                   1                    81                   0
# 3                   0                     0                   0
# 4                   0                     0                   0
# 5                   0                     0                   0
# 6                   0                     0                   0
#
#    daily_chance_of_snow      condition_text  \
# 0                     0               Sunny
# 1                     0  Patchy rain nearby
# 2                     0  Patchy rain nearby
# 3                     0               Sunny
# 4                     0               Sunny
# 5                     0               Sunny
# 6                     0               Sunny
#
#                                    condition_icon
# 0  //cdn.weatherapi.com/weather/64x64/day/113.png
# 1  //cdn.weatherapi.com/weather/64x64/day/176.png
# 2  //cdn.weatherapi.com/weather/64x64/day/176.png
# 3  //cdn.weatherapi.com/weather/64x64/day/113.png
# 4  //cdn.weatherapi.com/weather/64x64/day/113.png
# 5  //cdn.weatherapi.com/weather/64x64/day/113.png
# 6  //cdn.weatherapi.com/weather/64x64/day/113.png

# %%
df_meteo['date'] = pd.to_datetime(df_meteo['date'])

# %%
hour_data = []
for day in data['forecast']['forecastday']:
    print(day['date'])
    for hour in day['hour']:
        hour_data.append({
            'date': day['date'],
            'hour': hour['time'],
            'precipitation': hour['precip_mm'],
        })
df_hour = pd.DataFrame(hour_data)
# Out:
# 2025-07-08
# 2025-07-09
# 2025-07-10

# %%
fig = px.area(
    df_hour,
    x="hour",
    y="precipitation",
    labels=False,
    title="Prévisions des Précipitations (en mm)",
)
fig.update_layout(
    title={
        "text": "Prévisions des Précipitations (en mm)",
        "font": {
            "family": "Open Sans",  # Police choisie
            "size": 24,  # Taille du titre
        },
        "x": 0.5,  # Centrer le titre
        "xanchor": "center",  # Ancrage du titre
    },
    xaxis_title=None,
    yaxis_title=None,
)
fig.update_traces(
    line_color="#57bb8a",
    fillcolor="rgba(87, 187, 138, 0.4)",  # couleur en semi-transparent
)

# %%
total_precipitation = 0
for day in data['forecast']['forecastday']:
    total_precipitation += day['day']['totalprecip_mm']
    print(f"Total precipitation for {day['date']}: {day['day']['totalprecip_mm']} mm")
# Out:
# Total precipitation for 2025-07-08: 0.53 mm
# Total precipitation for 2025-07-09: 13.58 mm
# Total precipitation for 2025-07-10: 1.27 mm

# %%
total_precipitation
# Out:
# 15.379999999999999
