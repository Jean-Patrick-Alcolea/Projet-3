# %%
import requests
import pandas as pd

# %%
API_key = '0cdc8fe6b816033ac2bb235f68c8a328'
url = f'https://api.openweathermap.org/data/2.5/onecall?lat=33.44&lon=-94.04&appid={API_key}'
response = requests.get(url)
response
# Out:
# <Response [401]>

# %%
API_key = "d37cba2af0fad64bbe4353f7b391a42a"
lat = 33.44
lon = -94.04

url = f"https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&appid={API_key}&units=metric"
response = requests.get(url)

print(response.status_code)
print(response.text)
# Out:
# 401
# {"cod":401, "message": "Please note that using One Call 3.0 requires a separate subscription to the One Call by Call plan. Learn more here https://openweathermap.org/price. If you have a valid subscription to the One Call by Call plan, but still receive this error, then please see https://openweathermap.org/faq#error401 for more info."}

# %%
params = {
    'key' : '2fbbaab3e35841d5ba0125329251906',
    'q' : '33.44,-94.04',
    'days' : 2}

url2 = 'http://api.weatherapi.com/v1/forecast.json'
response2 = requests.get(url2, params=params)
print(response2.status_code)
# Out:
# 200

# %%
data = response2.json()

# %%
data['forecast']['forecastday'][0]
# Out:
# {'date': '2025-06-19',
#  'date_epoch': 1750291200,
#  'day': {'maxtemp_c': 33.8,
#   'maxtemp_f': 92.8,
#   'mintemp_c': 23.9,
#   'mintemp_f': 75.0,
#   'avgtemp_c': 28.5,
#   'avgtemp_f': 83.2,
#   'maxwind_mph': 8.5,
#   'maxwind_kph': 13.7,
#   'totalprecip_mm': 0.0,
#   'totalprecip_in': 0.0,
#   'totalsnow_cm': 0.0,
#   'avgvis_km': 9.0,
#   'avgvis_miles': 5.0,
#   'avghumidity': 77,
#   'daily_will_it_rain': 0,
#   'daily_chance_of_rain': 0,
#   'daily_will_it_snow': 0,
#   'daily_chance_of_snow': 0,
#   'condition': {'text': 'Thundery outbreaks in nearby',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/200.png',
#    'code': 1087},
#   'uv': 2.5},
#  'astro': {'sunrise': '06:06 AM',
#   'sunset': '08:29 PM',
#   'moonrise': '01:33 AM',
#   'moonset': '02:19 PM',
#   'moon_phase': 'Waning Crescent',
#   'moon_illumination': 48,
#   'is_moon_up': 0,
#   'is_sun_up': 0},
#  'hour': [{'time_epoch': 1750309200,
#    'time': '2025-06-19 00:00',
#    'temp_c': 27.3,
#    'temp_f': 81.2,
#    'is_day': 0,
#    'condition': {'text': 'Clear ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#     'code': 1000},
#    'wind_mph': 6.9,
#    'wind_kph': 11.2,
#    'wind_degree': 207,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1014.0,
#    'pressure_in': 29.95,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 77,
#    'cloud': 13,
#    'feelslike_c': 30.5,
#    'feelslike_f': 86.8,
#    'windchill_c': 27.3,
#    'windchill_f': 81.2,
#    'heatindex_c': 30.5,
#    'heatindex_f': 86.8,
#    'dewpoint_c': 22.6,
#    'dewpoint_f': 72.7,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 14.6,
#    'gust_kph': 23.4,
#    'uv': 0},
#   {'time_epoch': 1750312800,
#    'time': '2025-06-19 01:00',
#    'temp_c': 27.1,
#    'temp_f': 80.7,
#    'is_day': 0,
#    'condition': {'text': 'Cloudy ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#     'code': 1006},
#    'wind_mph': 7.4,
#    'wind_kph': 11.9,
#    'wind_degree': 212,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1015.0,
#    'pressure_in': 29.96,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 77,
#    'cloud': 72,
#    'feelslike_c': 30.1,
#    'feelslike_f': 86.1,
#    'windchill_c': 27.1,
#    'windchill_f': 80.7,
#    'heatindex_c': 30.1,
#    'heatindex_f': 86.1,
#    'dewpoint_c': 22.5,
#    'dewpoint_f': 72.6,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 15.5,
#    'gust_kph': 24.9,
#    'uv': 0},
#   {'time_epoch': 1750316400,
#    'time': '2025-06-19 02:00',
#    'temp_c': 26.4,
#    'temp_f': 79.5,
#    'is_day': 0,
#    'condition': {'text': 'Clear ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#     'code': 1000},
#    'wind_mph': 6.9,
#    'wind_kph': 11.2,
#    'wind_degree': 219,
#    'wind_dir': 'SW',
#    'pressure_mb': 1014.0,
#    'pressure_in': 29.96,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 78,
#    'cloud': 9,
#    'feelslike_c': 29.2,
#    'feelslike_f': 84.5,
#    'windchill_c': 26.4,
#    'windchill_f': 79.5,
#    'heatindex_c': 29.2,
#    'heatindex_f': 84.5,
#    'dewpoint_c': 22.6,
#    'dewpoint_f': 72.7,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 14.6,
#    'gust_kph': 23.4,
#    'uv': 0},
#   {'time_epoch': 1750320000,
#    'time': '2025-06-19 03:00',
#    'temp_c': 25.6,
#    'temp_f': 78.1,
#    'is_day': 0,
#    'condition': {'text': 'Clear ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#     'code': 1000},
#    'wind_mph': 6.7,
#    'wind_kph': 10.8,
#    'wind_degree': 218,
#    'wind_dir': 'SW',
#    'pressure_mb': 1015.0,
#    'pressure_in': 29.97,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 83,
#    'cloud': 12,
#    'feelslike_c': 28.2,
#    'feelslike_f': 82.8,
#    'windchill_c': 25.6,
#    'windchill_f': 78.1,
#    'heatindex_c': 28.2,
#    'heatindex_f': 82.8,
#    'dewpoint_c': 22.6,
#    'dewpoint_f': 72.6,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 14.1,
#    'gust_kph': 22.7,
#    'uv': 0},
#   {'time_epoch': 1750323600,
#    'time': '2025-06-19 04:00',
#    'temp_c': 24.9,
#    'temp_f': 76.9,
#    'is_day': 0,
#    'condition': {'text': 'Partly Cloudy ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#     'code': 1003},
#    'wind_mph': 6.5,
#    'wind_kph': 10.4,
#    'wind_degree': 213,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1016.0,
#    'pressure_in': 29.99,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 87,
#    'cloud': 40,
#    'feelslike_c': 27.4,
#    'feelslike_f': 81.4,
#    'windchill_c': 24.9,
#    'windchill_f': 76.9,
#    'heatindex_c': 27.4,
#    'heatindex_f': 81.4,
#    'dewpoint_c': 22.5,
#    'dewpoint_f': 72.4,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 13.6,
#    'gust_kph': 21.9,
#    'uv': 0},
#   {'time_epoch': 1750327200,
#    'time': '2025-06-19 05:00',
#    'temp_c': 24.4,
#    'temp_f': 76.0,
#    'is_day': 0,
#    'condition': {'text': 'Overcast ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 6.3,
#    'wind_kph': 10.1,
#    'wind_degree': 217,
#    'wind_dir': 'SW',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.01,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 89,
#    'cloud': 91,
#    'feelslike_c': 26.8,
#    'feelslike_f': 80.3,
#    'windchill_c': 24.4,
#    'windchill_f': 76.0,
#    'heatindex_c': 26.8,
#    'heatindex_f': 80.3,
#    'dewpoint_c': 22.4,
#    'dewpoint_f': 72.2,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 12.9,
#    'gust_kph': 20.8,
#    'uv': 0},
#   {'time_epoch': 1750330800,
#    'time': '2025-06-19 06:00',
#    'temp_c': 24.5,
#    'temp_f': 76.0,
#    'is_day': 0,
#    'condition': {'text': 'Overcast ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#     'code': 1009},
#    'wind_mph': 5.8,
#    'wind_kph': 9.4,
#    'wind_degree': 220,
#    'wind_dir': 'SW',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.01,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 91,
#    'cloud': 100,
#    'feelslike_c': 26.9,
#    'feelslike_f': 80.4,
#    'windchill_c': 24.5,
#    'windchill_f': 76.0,
#    'heatindex_c': 26.9,
#    'heatindex_f': 80.4,
#    'dewpoint_c': 22.4,
#    'dewpoint_f': 72.3,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 2.0,
#    'vis_miles': 1.0,
#    'gust_mph': 11.8,
#    'gust_kph': 18.9,
#    'uv': 0},
#   {'time_epoch': 1750334400,
#    'time': '2025-06-19 07:00',
#    'temp_c': 25.3,
#    'temp_f': 77.5,
#    'is_day': 1,
#    'condition': {'text': 'Overcast ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#     'code': 1009},
#    'wind_mph': 5.1,
#    'wind_kph': 8.3,
#    'wind_degree': 233,
#    'wind_dir': 'SW',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.04,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 90,
#    'cloud': 93,
#    'feelslike_c': 28.1,
#    'feelslike_f': 82.5,
#    'windchill_c': 25.3,
#    'windchill_f': 77.5,
#    'heatindex_c': 28.1,
#    'heatindex_f': 82.5,
#    'dewpoint_c': 22.7,
#    'dewpoint_f': 72.9,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 9.1,
#    'gust_kph': 14.7,
#    'uv': 0.2},
#   {'time_epoch': 1750338000,
#    'time': '2025-06-19 08:00',
#    'temp_c': 26.7,
#    'temp_f': 80.1,
#    'is_day': 1,
#    'condition': {'text': 'Thundery outbreaks in nearby',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/200.png',
#     'code': 1087},
#    'wind_mph': 7.4,
#    'wind_kph': 11.9,
#    'wind_degree': 252,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.06,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 90,
#    'cloud': 0,
#    'feelslike_c': 29.5,
#    'feelslike_f': 85.1,
#    'windchill_c': 26.3,
#    'windchill_f': 79.3,
#    'heatindex_c': 29.5,
#    'heatindex_f': 85.1,
#    'dewpoint_c': 23.5,
#    'dewpoint_f': 74.2,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 16.0,
#    'vis_miles': 9.0,
#    'gust_mph': 10.1,
#    'gust_kph': 16.2,
#    'uv': 0.3},
#   {'time_epoch': 1750341600,
#    'time': '2025-06-19 09:00',
#    'temp_c': 26.1,
#    'temp_f': 79.0,
#    'is_day': 1,
#    'condition': {'text': 'Thundery outbreaks in nearby',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/200.png',
#     'code': 1087},
#    'wind_mph': 8.1,
#    'wind_kph': 13.0,
#    'wind_degree': 257,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.07,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 80,
#    'cloud': 49,
#    'feelslike_c': 29.2,
#    'feelslike_f': 84.6,
#    'windchill_c': 26.1,
#    'windchill_f': 79.0,
#    'heatindex_c': 29.2,
#    'heatindex_f': 84.6,
#    'dewpoint_c': 23.6,
#    'dewpoint_f': 74.5,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 10.4,
#    'gust_kph': 16.7,
#    'uv': 0.6},
#   {'time_epoch': 1750345200,
#    'time': '2025-06-19 10:00',
#    'temp_c': 27.6,
#    'temp_f': 81.7,
#    'is_day': 1,
#    'condition': {'text': 'Thundery outbreaks in nearby',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/200.png',
#     'code': 1087},
#    'wind_mph': 8.1,
#    'wind_kph': 13.0,
#    'wind_degree': 262,
#    'wind_dir': 'W',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.08,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 87,
#    'cloud': 100,
#    'feelslike_c': 31.5,
#    'feelslike_f': 88.7,
#    'windchill_c': 27.6,
#    'windchill_f': 81.7,
#    'heatindex_c': 31.5,
#    'heatindex_f': 88.7,
#    'dewpoint_c': 23.5,
#    'dewpoint_f': 74.3,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 10.0,
#    'gust_kph': 16.2,
#    'uv': 2.3},
#   {'time_epoch': 1750348800,
#    'time': '2025-06-19 11:00',
#    'temp_c': 28.4,
#    'temp_f': 83.2,
#    'is_day': 1,
#    'condition': {'text': 'Thundery outbreaks in nearby',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/200.png',
#     'code': 1087},
#    'wind_mph': 8.3,
#    'wind_kph': 13.3,
#    'wind_degree': 256,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.08,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 74,
#    'cloud': 79,
#    'feelslike_c': 32.8,
#    'feelslike_f': 91.1,
#    'windchill_c': 28.4,
#    'windchill_f': 83.2,
#    'heatindex_c': 32.8,
#    'heatindex_f': 91.1,
#    'dewpoint_c': 24.1,
#    'dewpoint_f': 75.3,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 9.8,
#    'gust_kph': 15.8,
#    'uv': 6.6},
#   {'time_epoch': 1750352400,
#    'time': '2025-06-19 12:00',
#    'temp_c': 28.0,
#    'temp_f': 82.4,
#    'is_day': 1,
#    'condition': {'text': 'Thundery outbreaks in nearby',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/200.png',
#     'code': 1087},
#    'wind_mph': 8.5,
#    'wind_kph': 13.7,
#    'wind_degree': 247,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.07,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 74,
#    'cloud': 62,
#    'feelslike_c': 32.2,
#    'feelslike_f': 90.0,
#    'windchill_c': 28.0,
#    'windchill_f': 82.4,
#    'heatindex_c': 32.2,
#    'heatindex_f': 90.0,
#    'dewpoint_c': 24.1,
#    'dewpoint_f': 75.4,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 9.9,
#    'gust_kph': 15.9,
#    'uv': 8.4},
#   {'time_epoch': 1750356000,
#    'time': '2025-06-19 13:00',
#    'temp_c': 30.0,
#    'temp_f': 85.9,
#    'is_day': 1,
#    'condition': {'text': 'Thundery outbreaks in nearby',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/200.png',
#     'code': 1087},
#    'wind_mph': 8.3,
#    'wind_kph': 13.3,
#    'wind_degree': 244,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.07,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 81,
#    'cloud': 85,
#    'feelslike_c': 35.3,
#    'feelslike_f': 95.6,
#    'windchill_c': 30.0,
#    'windchill_f': 85.9,
#    'heatindex_c': 35.3,
#    'heatindex_f': 95.6,
#    'dewpoint_c': 24.1,
#    'dewpoint_f': 75.3,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 9.5,
#    'gust_kph': 15.3,
#    'uv': 10.3},
#   {'time_epoch': 1750359600,
#    'time': '2025-06-19 14:00',
#    'temp_c': 31.3,
#    'temp_f': 88.4,
#    'is_day': 1,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'wind_mph': 8.1,
#    'wind_kph': 13.0,
#    'wind_degree': 242,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.05,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 65,
#    'cloud': 20,
#    'feelslike_c': 37.4,
#    'feelslike_f': 99.3,
#    'windchill_c': 31.3,
#    'windchill_f': 88.4,
#    'heatindex_c': 37.4,
#    'heatindex_f': 99.3,
#    'dewpoint_c': 24.5,
#    'dewpoint_f': 76.2,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 5.0,
#    'vis_miles': 3.0,
#    'gust_mph': 9.7,
#    'gust_kph': 15.7,
#    'uv': 10.4},
#   {'time_epoch': 1750363200,
#    'time': '2025-06-19 15:00',
#    'temp_c': 32.2,
#    'temp_f': 90.0,
#    'is_day': 1,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'wind_mph': 7.4,
#    'wind_kph': 11.9,
#    'wind_degree': 242,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.03,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 62,
#    'cloud': 20,
#    'feelslike_c': 39.2,
#    'feelslike_f': 102.5,
#    'windchill_c': 32.2,
#    'windchill_f': 90.0,
#    'heatindex_c': 39.2,
#    'heatindex_f': 102.5,
#    'dewpoint_c': 24.5,
#    'dewpoint_f': 76.0,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 9.6,
#    'gust_kph': 15.5,
#    'uv': 8.7},
#   {'time_epoch': 1750366800,
#    'time': '2025-06-19 16:00',
#    'temp_c': 33.0,
#    'temp_f': 91.4,
#    'is_day': 1,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'wind_mph': 4.9,
#    'wind_kph': 7.9,
#    'wind_degree': 270,
#    'wind_dir': 'W',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.02,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 63,
#    'cloud': 4,
#    'feelslike_c': 40.4,
#    'feelslike_f': 104.6,
#    'windchill_c': 33.0,
#    'windchill_f': 91.4,
#    'heatindex_c': 40.4,
#    'heatindex_f': 104.6,
#    'dewpoint_c': 25.2,
#    'dewpoint_f': 77.3,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 7.9,
#    'gust_kph': 12.6,
#    'uv': 6.3},
#   {'time_epoch': 1750370400,
#    'time': '2025-06-19 17:00',
#    'temp_c': 33.2,
#    'temp_f': 91.7,
#    'is_day': 1,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'wind_mph': 3.6,
#    'wind_kph': 5.8,
#    'wind_degree': 309,
#    'wind_dir': 'NW',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.0,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 60,
#    'cloud': 9,
#    'feelslike_c': 40.4,
#    'feelslike_f': 104.8,
#    'windchill_c': 33.2,
#    'windchill_f': 91.7,
#    'heatindex_c': 40.4,
#    'heatindex_f': 104.8,
#    'dewpoint_c': 24.8,
#    'dewpoint_f': 76.7,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 6.3,
#    'gust_kph': 10.1,
#    'uv': 3.7},
#   {'time_epoch': 1750374000,
#    'time': '2025-06-19 18:00',
#    'temp_c': 32.4,
#    'temp_f': 90.3,
#    'is_day': 1,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'wind_mph': 3.4,
#    'wind_kph': 5.4,
#    'wind_degree': 327,
#    'wind_dir': 'NNW',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.0,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 60,
#    'cloud': 11,
#    'feelslike_c': 39.5,
#    'feelslike_f': 103.1,
#    'windchill_c': 32.4,
#    'windchill_f': 90.3,
#    'heatindex_c': 39.5,
#    'heatindex_f': 103.1,
#    'dewpoint_c': 24.6,
#    'dewpoint_f': 76.2,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 6.4,
#    'gust_kph': 10.3,
#    'uv': 1.7},
#   {'time_epoch': 1750377600,
#    'time': '2025-06-19 19:00',
#    'temp_c': 31.7,
#    'temp_f': 89.0,
#    'is_day': 1,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'wind_mph': 2.2,
#    'wind_kph': 3.6,
#    'wind_degree': 312,
#    'wind_dir': 'NW',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.0,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 68,
#    'cloud': 2,
#    'feelslike_c': 38.3,
#    'feelslike_f': 101.0,
#    'windchill_c': 31.7,
#    'windchill_f': 89.0,
#    'heatindex_c': 38.3,
#    'heatindex_f': 101.0,
#    'dewpoint_c': 25.1,
#    'dewpoint_f': 77.1,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 4.4,
#    'gust_kph': 7.0,
#    'uv': 0.5},
#   {'time_epoch': 1750381200,
#    'time': '2025-06-19 20:00',
#    'temp_c': 30.8,
#    'temp_f': 87.4,
#    'is_day': 1,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'wind_mph': 4.5,
#    'wind_kph': 7.2,
#    'wind_degree': 266,
#    'wind_dir': 'W',
#    'pressure_mb': 1016.0,
#    'pressure_in': 29.99,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 69,
#    'cloud': 13,
#    'feelslike_c': 36.9,
#    'feelslike_f': 98.4,
#    'windchill_c': 30.8,
#    'windchill_f': 87.4,
#    'heatindex_c': 36.9,
#    'heatindex_f': 98.4,
#    'dewpoint_c': 24.6,
#    'dewpoint_f': 76.3,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 9.4,
#    'gust_kph': 15.1,
#    'uv': 0.0},
#   {'time_epoch': 1750384800,
#    'time': '2025-06-19 21:00',
#    'temp_c': 29.4,
#    'temp_f': 84.9,
#    'is_day': 0,
#    'condition': {'text': 'Clear ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#     'code': 1000},
#    'wind_mph': 3.8,
#    'wind_kph': 6.1,
#    'wind_degree': 257,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.0,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 73,
#    'cloud': 0,
#    'feelslike_c': 35.2,
#    'feelslike_f': 95.4,
#    'windchill_c': 29.4,
#    'windchill_f': 84.9,
#    'heatindex_c': 35.2,
#    'heatindex_f': 95.4,
#    'dewpoint_c': 24.6,
#    'dewpoint_f': 76.3,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 8.0,
#    'gust_kph': 12.9,
#    'uv': 0},
#   {'time_epoch': 1750388400,
#    'time': '2025-06-19 22:00',
#    'temp_c': 28.9,
#    'temp_f': 84.1,
#    'is_day': 0,
#    'condition': {'text': 'Clear ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#     'code': 1000},
#    'wind_mph': 2.9,
#    'wind_kph': 4.7,
#    'wind_degree': 276,
#    'wind_dir': 'W',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.01,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 87,
#    'cloud': 3,
#    'feelslike_c': 34.4,
#    'feelslike_f': 93.9,
#    'windchill_c': 28.9,
#    'windchill_f': 84.1,
#    'heatindex_c': 34.4,
#    'heatindex_f': 93.9,
#    'dewpoint_c': 25.7,
#    'dewpoint_f': 78.2,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 6.1,
#    'gust_kph': 9.8,
#    'uv': 0},
#   {'time_epoch': 1750392000,
#    'time': '2025-06-19 23:00',
#    'temp_c': 28.4,
#    'temp_f': 83.2,
#    'is_day': 0,
#    'condition': {'text': 'Clear ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#     'code': 1000},
#    'wind_mph': 2.2,
#    'wind_kph': 3.6,
#    'wind_degree': 261,
#    'wind_dir': 'W',
#    'pressure_mb': 1016.0,
#    'pressure_in': 30.02,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'snow_cm': 0.0,
#    'humidity': 80,
#    'cloud': 4,
#    'feelslike_c': 33.4,
#    'feelslike_f': 92.1,
#    'windchill_c': 28.4,
#    'windchill_f': 83.2,
#    'heatindex_c': 33.4,
#    'heatindex_f': 92.1,
#    'dewpoint_c': 24.8,
#    'dewpoint_f': 76.6,
#    'will_it_rain': 0,
#    'chance_of_rain': 0,
#    'will_it_snow': 0,
#    'chance_of_snow': 0,
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.7,
#    'gust_kph': 7.6,
#    'uv': 0}]}

# %%
for i in range(2):
    print(data['forecast']['forecastday'][i]['day'].get('avgtemp_c'),)
# Out:
# 28.5
# 29.8
