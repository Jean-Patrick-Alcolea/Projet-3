# %%
import pandas as pd

# %%
df_plantes_photos = pd.read_csv('../data/plantes_photos.csv')

# %%
df_plantes_photos.sample(10)
# Out:
#     Unnamed: 0.1  Unnamed: 0                   Nom                Type  \
# 80            80          83  Salsifi (Scorsonère)             Légumes
# 50            50          52             Coriandre         Aromatiques
# 21            21          22               Curcuma         Aromatiques
# 25            25          26             Camomille              Fleurs
# 54            54          56       Cresson alénois             Légumes
# 45            45          47             Chou rave             Légumes
# 68            68          71                Panais             Légumes
# 81            81          84                  Thym         Aromatiques
# 71            71          74                Piment             Légumes
# 30            30          32             Artichaut  Légumes perpétuels
#
#    Exposition             Rusticité Profondeur Espacement Temps_levée  \
# 80     Soleil      Résistant au gel      1 cm      10 cm     15 jours
# 50     Soleil  Non résistant au gel      1 cm      15 cm     15 jours
# 21   Mi-ombre      Résistant au gel        NaN        NaN         NaN
# 25     Soleil  Non résistant au gel       1 cm      25 cm    15 jours
# 54   Mi-ombre      Résistant au gel    0.5 cm      15 cm      4 jours
# 45     Soleil      Résistant au gel    0.5 cm      20 cm      8 jours
# 68     Soleil      Résistant au gel      1 cm      10 cm     28 jours
# 81     Soleil      Résistant au gel    0.5 cm      25 cm     21 jours
# 71     Soleil  Non résistant au gel    0.5 cm      50 cm     15 jours
# 30     Soleil      Résistant au gel      4 cm      80 cm     20 jours
#
#    Temperature delai_recolte  \
# 80       15 °C     150 jours
# 50       15 °C      60 jours
# 21         NaN           NaN
# 25       15 °C           NaN
# 54       15 °C      80 jours
# 45       12 °C     150 jours
# 68       18 °C     180 jours
# 81       20 °C     150 jours
# 71       15 °C     150 jours
# 30       15 °C     120 jours
#
#                                                 image
# 80  https://img.permapotes.com/cover-square/8b1faa...
# 50  https://img.permapotes.com/cover-square/7b61c4...
# 21  https://img.permapotes.com/cover-square/f41230...
# 25  https://img.permapotes.com/cover-square/456fb6...
# 54  https://img.permapotes.com/cover-square/b593f1...
# 45  https://img.permapotes.com/cover-square/13cd1e...
# 68  https://img.permapotes.com/cover-square/278229...
# 81  https://img.permapotes.com/cover-square/0f0e3a...
# 71  https://img.permapotes.com/cover-square/aa9aaa...
# 30  https://img.permapotes.com/cover-square/f69fa9...

# %%
df_plantes_photos['Espacement'].value_counts()
# Out:
# Espacement
# 10 cm      13
# 60 cm       6
# 50 cm       5
# 20 cm       4
# 15 cm       4
# 8 cm        4
# 40 cm       4
# 120 cm      4
# 30 cm       3
# 4 cm        3
# 100 cm      2
# 70 cm       2
# 25 cm       2
# 5 cm        2
# 25 cm       2
# 80 cm       2
# 30 cm       2
# 15 cm       2
# 10 cm       1
# 20 cm       1
# 60 cm       1
# 120 cm      1
# 2 cm        1
# 12 cm       1
# 80 cm       1
# 100 cm      1
# Name: count, dtype: int64

# %%
df_plantes_photos.loc[29, 'delai_recolte'] = None

# %%
df_plantes_photos['delai_recolte'].isna()
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 79     True
# 80    False
# 81     True
# 82     True
# 83     True
# Name: delai_recolte, Length: 84, dtype: bool

# %%
#Reset index
#Enelver cm profondeur et espacement
#enlever " °C" à Temperature
#enlever jours à delai_récolte
# temps_levée, temperature et delai_recole en int
#profondeur, espacement en float

# %%
df_plantes_photos['Profondeur'] = df_plantes_photos['Profondeur'].str.replace(' cm', '').str.replace(' ', '')
df_plantes_photos['Espacement'] = df_plantes_photos['Espacement'].str.replace(' cm', '').str.replace(' ', '')
df_plantes_photos['Temps_levée'] = df_plantes_photos['Temps_levée'].str.replace(' jours', '').str.replace(' ', '')
df_plantes_photos['delai_recolte'] = df_plantes_photos['delai_recolte'].str.replace(' jours', '').str.replace(' ', '')
df_plantes_photos['Temperature'] = df_plantes_photos['Temperature'].str.replace(' °C', '').str.replace(' ', '')
#df_plantes_photos.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df_plantes_photos.sort_values(['Type', 'Nom'], inplace=True)
df_plantes_photos.reset_index(drop=True, inplace=True)

# %%
df_plantes_photos.head(10)
# Out:
#           Nom         Type Exposition             Rusticité Profondeur  \
# 0       Aneth  Aromatiques     Soleil      Résistant au gel        0.5
# 1     Basilic  Aromatiques     Soleil  Non résistant au gel        0.5
# 2    Cerfeuil  Aromatiques   Mi-ombre      Résistant au gel        0.5
# 3  Ciboulette  Aromatiques     Soleil      Résistant au gel          1
# 4   Coriandre  Aromatiques     Soleil  Non résistant au gel          1
# 5     Curcuma  Aromatiques   Mi-ombre      Résistant au gel        NaN
# 6    Estragon  Aromatiques     Soleil      Résistant au gel        NaN
# 7   Gingembre  Aromatiques     Soleil  Non résistant au gel        NaN
# 8      Menthe  Aromatiques   Mi-ombre      Résistant au gel        NaN
# 9      Origan  Aromatiques     Soleil      Résistant au gel        NaN
#
#   Espacement Temps_levée Temperature delai_recolte  \
# 0         20          20          18          None
# 1         20           8          18            90
# 2         10          10          10            50
# 3         10          18          18            90
# 4         15          15          15            60
# 5        NaN         NaN         NaN           NaN
# 6         20         NaN         NaN           NaN
# 7        NaN         NaN         NaN           NaN
# 8        NaN         NaN         NaN           NaN
# 9         30         NaN         NaN           NaN
#
#                                                image
# 0  https://img.permapotes.com/cover-square/197d40...
# 1  https://img.permapotes.com/cover-square/8b9aa5...
# 2  https://img.permapotes.com/cover-square/67265a...
# 3  https://img.permapotes.com/cover-square/d0db40...
# 4  https://img.permapotes.com/cover-square/7b61c4...
# 5  https://img.permapotes.com/cover-square/f41230...
# 6  https://img.permapotes.com/cover-square/d0078a...
# 7  https://img.permapotes.com/cover-square/e2eb00...
# 8  https://img.permapotes.com/cover-square/2b346d...
# 9  https://img.permapotes.com/cover-square/6cd5f9...

# %%
df_plantes_photos['delai_recolte'].value_counts()
# Out:
# delai_recolte
# 150    15
# 90     12
# 120     9
# 180     7
# 100     3
# 210     3
# 80      2
# 75      2
# 60      2
# 50      1
# 140     1
# 730     1
# 70      1
# 40      1
# Name: count, dtype: int64

# %%
round(df_plantes_photos['Type'].value_counts(normalize=True) * 100,2)
# Out:
# Type
# Légumes               60.71
# Aromatiques           16.67
# Fruitiers             11.90
# Légumes perpétuels     5.95
# Fleurs                 4.76
# Name: proportion, dtype: float64

# %%
df_plantes_photos['Espacement'] = df_plantes_photos['Espacement'].astype('Int64')
df_plantes_photos['Profondeur'] = df_plantes_photos['Profondeur'].astype(float)
df_plantes_photos['Temps_levée'] = df_plantes_photos['Temps_levée'].astype('Int64')

# %%
df_plantes_photos.sample(10)
# Out:
#                      Nom                Type Exposition             Rusticité  \
# 51               Epinard             Légumes   Mi-ombre      Résistant au gel
# 75  Salsifi (Scorsonère)             Légumes     Soleil      Résistant au gel
# 48           Céleri rave             Légumes     Soleil      Résistant au gel
# 83              Rhubarbe  Légumes perpétuels   Mi-ombre      Résistant au gel
# 37            Chou cabus             Légumes     Soleil      Résistant au gel
# 13                  Thym         Aromatiques     Soleil      Résistant au gel
# 36        Chou Romanesco             Légumes     Soleil      Résistant au gel
# 73  Radis noir (d'hiver)             Légumes     Soleil  Non résistant au gel
# 74           Radis rouge             Légumes   Mi-ombre      Résistant au gel
# 44                Courge             Légumes     Soleil  Non résistant au gel
#
#     Profondeur  Espacement  Temps_levée Temperature delai_recolte  \
# 51         1.0        10.0           10          10            60
# 75         1.0        10.0           15          15           150
# 48         0.5        30.0           18          15           210
# 83         NaN       100.0         <NA>         NaN           NaN
# 37         1.0        60.0            6          12           150
# 13         0.5        25.0           21          20           150
# 36         1.0        70.0            5          12           100
# 73         0.5         8.0            5           8           150
# 74         0.5         8.0            5           8            40
# 44         2.0       120.0            8          15           150
#
#                                                 image
# 51  https://img.permapotes.com/cover-square/fd57bb...
# 75  https://img.permapotes.com/cover-square/8b1faa...
# 48  https://img.permapotes.com/cover-square/25a003...
# 83  https://img.permapotes.com/cover-square/3be940...
# 37  https://img.permapotes.com/cover-square/dfd7d2...
# 13  https://img.permapotes.com/cover-square/0f0e3a...
# 36  https://img.permapotes.com/cover-square/b2b2d0...
# 73  https://img.permapotes.com/cover-square/b45d63...
# 74  https://img.permapotes.com/cover-square/586765...
# 44  https://img.permapotes.com/cover-square/8a30b5...

# %%
df_plantes_photos['delai_recolte'].value_counts()
# Out:
# delai_recolte
# 150         15
# 90          12
# 120          9
# 180          7
# 100          3
# 210          3
# 60           2
# 80           2
# 75           2
# 3 années     1
# 50           1
# 140          1
# 730          1
# 70           1
# 40           1
# Name: count, dtype: int64

# %%
df_plantes_photos.head(10)
# Out:
#           Nom         Type Exposition             Rusticité  Profondeur  \
# 0       Aneth  Aromatiques     Soleil      Résistant au gel         0.5
# 1     Basilic  Aromatiques     Soleil  Non résistant au gel         0.5
# 2    Cerfeuil  Aromatiques   Mi-ombre      Résistant au gel         0.5
# 3  Ciboulette  Aromatiques     Soleil      Résistant au gel         1.0
# 4   Coriandre  Aromatiques     Soleil  Non résistant au gel         1.0
# 5     Curcuma  Aromatiques   Mi-ombre      Résistant au gel         NaN
# 6    Estragon  Aromatiques     Soleil      Résistant au gel         NaN
# 7   Gingembre  Aromatiques     Soleil  Non résistant au gel         NaN
# 8      Menthe  Aromatiques   Mi-ombre      Résistant au gel         NaN
# 9      Origan  Aromatiques     Soleil      Résistant au gel         NaN
#
#    Espacement  Temps_levée Temperature delai_recolte  \
# 0          20           20          18          None
# 1          20            8          18            90
# 2          10           10          10            50
# 3          10           18          18            90
# 4          15           15          15            60
# 5        <NA>         <NA>         NaN           NaN
# 6          20         <NA>         NaN           NaN
# 7        <NA>         <NA>         NaN           NaN
# 8        <NA>         <NA>         NaN           NaN
# 9          30         <NA>         NaN           NaN
#
#                                                image
# 0  https://img.permapotes.com/cover-square/197d40...
# 1  https://img.permapotes.com/cover-square/8b9aa5...
# 2  https://img.permapotes.com/cover-square/67265a...
# 3  https://img.permapotes.com/cover-square/d0db40...
# 4  https://img.permapotes.com/cover-square/7b61c4...
# 5  https://img.permapotes.com/cover-square/f41230...
# 6  https://img.permapotes.com/cover-square/d0078a...
# 7  https://img.permapotes.com/cover-square/e2eb00...
# 8  https://img.permapotes.com/cover-square/2b346d...
# 9  https://img.permapotes.com/cover-square/6cd5f9...

# %%
df_plantes_photos.to_csv('../data/df_plantes_clean.csv', index=False)
